# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
df=pd.read_csv('bank.csv')

# %%
df.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  30;"unemployed";"married";"primary";"no";1787;...
# 1  33;"services";"married";"secondary";"no";4789;...
# 2  35;"management";"single";"tertiary";"no";1350;...
# 3  30;"management";"married";"tertiary";"no";1476...
# 4  59;"blue-collar";"married";"secondary";"no";0;...

# %%
pd.read_csv('bank.csv',header=-1)
# Out:
#                                                       0
# 0     age;"job";"marital";"education";"default";"bal...
# 1     30;"unemployed";"married";"primary";"no";1787;...
# 2     33;"services";"married";"secondary";"no";4789;...
# 3     35;"management";"single";"tertiary";"no";1350;...
# 4     30;"management";"married";"tertiary";"no";1476...
# 5     59;"blue-collar";"married";"secondary";"no";0;...
# 6     35;"management";"single";"tertiary";"no";747;"...
# 7     36;"self-employed";"married";"tertiary";"no";3...
# 8     39;"technician";"married";"secondary";"no";147...
# 9     41;"entrepreneur";"married";"tertiary";"no";22...
# 10    43;"services";"married";"primary";"no";-88;"ye...
# 11    39;"services";"married";"secondary";"no";9374;...
# 12    43;"admin.";"married";"secondary";"no";264;"ye...
# 13    36;"technician";"married";"tertiary";"no";1109...
# 14    20;"student";"single";"secondary";"no";502;"no...
# 15    31;"blue-collar";"married";"secondary";"no";36...
# ...

# %%
df=pd.read_csv('bank.csv',header=-1)
df.head()
# Out:
#                                                    0
# 0  age;"job";"marital";"education";"default";"bal...
# 1  30;"unemployed";"married";"primary";"no";1787;...
# 2  33;"services";"married";"secondary";"no";4789;...
# 3  35;"management";"single";"tertiary";"no";1350;...
# 4  30;"management";"married";"tertiary";"no";1476...

# %%
 col_name=['age','job','marital','education','default','balance','housing','loan','contact','day','month','duration','campaign','pdays','previous','poutcome','y']

# %%
print(col_name)
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y']

# %%
print(df.columns)
# Out:
# Int64Index([0], dtype='int64')

# %%
df.columns=col_name
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-3d206f2e2753> in <module>()
# ----> 1 df.columns=col_name
#       2 df.head()
#
# ~\Anaconda3\envs\irisproject\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\envs\irisproject\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
#     560         self._clear_item_cache()
#     561
#
# ...

# %%
print(df.columns)
# Out:
# Int64Index([0], dtype='int64')

# %%
df.head()
# Out:
#                                                    0
# 0  age;"job";"marital";"education";"default";"bal...
# 1  30;"unemployed";"married";"primary";"no";1787;...
# 2  33;"services";"married";"secondary";"no";4789;...
# 3  35;"management";"single";"tertiary";"no";1350;...
# 4  30;"management";"married";"tertiary";"no";1476...

# %%
df = pd.read_csv("bank.csv",delimiter=";")
df.head(10)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %%
iris=sns.load_dataset("bank.csv")
iris.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-35-21322d585e66> in <module>()
# ----> 1 iris=sns.load_dataset('bank.csv')
#       2 iris.head()
#
# ~\Anaconda3\envs\irisproject\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     408                                   os.path.basename(full_path))
#     409         if not os.path.exists(cache_path):
# --> 410             urlretrieve(full_path, cache_path)
#     411         full_path = cache_path
#     412
#
# ~\Anaconda3\envs\irisproject\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     246     url_type, path = splittype(url)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#     250
#
# ...
